# %%
import joblib
import os
# Load environment variables from .env file
from dotenv import load_dotenv
# Data manipulation
import pandas as pd
# Data & Model evaluation
import sklearn
print(f"Scikit-Learn version: {sklearn.__version__}")

from scipy.stats import randint, uniform, loguniform
from sklearn.model_selection import RandomizedSearchCV, KFold, train_test_split, GridSearchCV


from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline

from sklearn.linear_model import Ridge, Lasso,LinearRegression
from sklearn.ensemble import HistGradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error, make_scorer

import warnings
warnings.filterwarnings("ignore", message="Found unknown categories")

# Visualisation
import plotly.express as px

# Custom utilities for IA
import fpcia as fp

# MLFlow
import mlflow
print(f"MLFlow version: {mlflow.__version__}")
from mlflow.models import infer_signature
from mlflow.tracking import MlflowClient
# Out:
# Scikit-Learn version: 1.8.0
# MLFlow version: 3.9.0

# %%
load_dotenv()

print(f"Pandas version: {pd.__version__}")
print(f"Scikit Learn version: {sklearn.__version__}")
print(f"MLFlow version: {mlflow.__version__}")
# Out:
# Pandas version: 2.3.3
# Scikit Learn version: 1.8.0
# MLFlow version: 3.9.0

# %% [markdown]
# ## Récupération du Dataset

# %% [markdown]
# Les données sont propres et ne nécessitent aucun traitement supplémentaire comme je le montre ci-dessous.

# %%
pricing_df = pd.read_csv("https://huggingface.co/datasets/pradelf/getaround-dataset/resolve/main/get_around_pricing_project.csv", index_col=0)
pricing_df.head()
# Out:
#    model_key  mileage  engine_power    fuel paint_color     car_type  \
# id
# 0    Citroën   140411           100  diesel       black  convertible
# 1    Citroën    13929           317  petrol        grey  convertible
# 2    Citroën   183297           120  diesel       white  convertible
# 3    Citroën   128035           135  diesel         red  convertible
# 4    Citroën    97097           160  diesel      silver  convertible
#
#     private_parking_available  has_gps  has_air_conditioning  automatic_car  \
# id
# 0                        True     True                 False          False
# 1                        True     True                 False          False
# 2                       False    False                 False          False
# 3                        True     True                 False          False
# 4                        True     True                 False          False
#
#     has_getaround_connect  has_speed_regulator  winter_tires  \
# id
# ...

# %% [markdown]
# ### Analyse du Dataset.

# %%
fp.eda.summary(pricing_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4843 entries, 0 to 4842
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   model_key                  4843 non-null   object
#  1   mileage                    4843 non-null   int64
#  2   engine_power               4843 non-null   int64
#  3   fuel                       4843 non-null   object
#  4   paint_color                4843 non-null   object
#  5   car_type                   4843 non-null   object
#  6   private_parking_available  4843 non-null   bool
#  7   has_gps                    4843 non-null   bool
#  8   has_air_conditioning       4843 non-null   bool
#  9   automatic_car              4843 non-null   bool
#  10  has_getaround_connect      4843 non-null   bool
#  11  has_speed_regulator        4843 non-null   bool
#  12  winter_tires               4843 non-null   bool
# ...

# %% [markdown]
# Comme nous l'avons vu dans le [notebook d'EDA](./02_Getaround_eda.ipynb), nous prenons pour des raisons de pertinence statistique un sous ensemble du dataset pour les voitures des marques suivantes :

# %%
marques = pricing_df['model_key'].value_counts()
marques=set(marques[marques >10].index.to_list())
marques
# Out:
# {'Audi',
#  'BMW',
#  'Citroën',
#  'Ferrari',
#  'Maserati',
#  'Mercedes',
#  'Mitsubishi',
#  'Nissan',
#  'Opel',
#  'PGO',
#  'Peugeot',
#  'Renault',
#  'SEAT',
#  'Subaru',
#  'Toyota',
#  'Volkswagen'}

# %% [markdown]
# Le dataset est donc réduit en filtrant avec un masque de ces marques.

# %%
pricing_df=pricing_df[pricing_df['model_key'].isin(marques)]
pricing_df.count()
# Out:
# model_key                    4808
# mileage                      4808
# engine_power                 4808
# fuel                         4808
# paint_color                  4808
# car_type                     4808
# private_parking_available    4808
# has_gps                      4808
# has_air_conditioning         4808
# automatic_car                4808
# has_getaround_connect        4808
# has_speed_regulator          4808
# winter_tires                 4808
# rental_price_per_day         4808
# dtype: int64

# %% [markdown]
# ## Modèle de base

# %% [markdown]
# La structure des données est simple.
#
# En effet, nous avons 13 "features" pour une valeur cible numérique à prédire : <br/>
# le tarif de location du véhicule (_rental_price_per_day_).<br/>
# Le modèle à obtenir est donc une regression sur le tarif de location du véhicule.<br/>
# Pour commencer, nous allons créer un modèle de regression linéaire qui sera le modèle de base.

# %%
from sklearn.impute import SimpleImputer


categorical_cols = ["model_key", "fuel", "paint_color", "car_type", "private_parking_available", "has_gps", "has_air_conditioning",
                    "automatic_car", "has_getaround_connect", "has_speed_regulator", "winter_tires"]
numerical_cols = ["mileage", "engine_power"]

X = pricing_df[categorical_cols + numerical_cols]
Y = pricing_df["rental_price_per_day"]

bins = pd.qcut(Y, q=4, duplicates="drop")
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y,
    train_size=0.75,
    random_state=42,
#    stratify=bins
)
cat_imputer=SimpleImputer(strategy="most_frequent")
onehot_encoder = OneHotEncoder(drop="first", handle_unknown="ignore")
categorical_transformer = Pipeline(steps=[
    ("imputer", cat_imputer),
    ("onehot", onehot_encoder)
])
standard_scaler = StandardScaler()
num_imputer=SimpleImputer(strategy="median")
numeric_transformer = Pipeline(steps=[
    ("imputer", num_imputer),
    ("scale", standard_scaler)
])
 

# Preprocessing des données avec ColumnTransformer pour appliquer les transformations appropriées aux colonnes catégorielles et numériques
preprocessor = ColumnTransformer(
    transformers=[
        ("numerical", numeric_transformer, numerical_cols),
        ("categorical", categorical_transformer, categorical_cols)   
    ]
)
# Application du préprocesseur aux données d'entraînement et de test
X_train_preprocessed = preprocessor.fit_transform(X_train)
X_test_preprocessed = preprocessor.transform(X_test)
# Out:
# 2026/03/10 00:44:05 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '48d53b12ba9049a5a900f81a716b7f9b', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# ...

# %% [markdown]
# ### Modèle de base 0 : Linear Regression

# %%
EXPERIMENT_NAME="getaround-price-prediction"
mlflow.set_tracking_uri(os.environ["TRACKING_SERVER_URL"])
mlflow.set_experiment(EXPERIMENT_NAME)
experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)

# Call mlflow autolog
mlflow.sklearn.autolog(registered_model_name="MODEL0")
run_description = """
### Modèle de Base de régression linéaire pour la prédiction du prix de location de voitures Getaround
Il s'agit du modèle de base de régression linéaire, qui sert de point de départ pour évaluer les performances des modèles plus complexes.
    """
with mlflow.start_run(experiment_id = experiment.experiment_id, run_name="Linear Regression", description=run_description) as run:
    regressor0 = LinearRegression()
    regressor0.fit(X_train_preprocessed, Y_train)
    print("Predictions on training set...")
    Y_train_pred = regressor0.predict(X_train_preprocessed)
    print("...Done.")
    print(Y_train_pred)
    print()
    print("Predictions on test set...")
    Y_test_pred = regressor0.predict(X_test_preprocessed)
    print("...Done.")
    print(Y_test_pred)
    print()
    r2_train = r2_score(Y_train, Y_train_pred)
    r2_test = r2_score(Y_test, Y_test_pred)
    mlflow.log_metric("train_r2", r2_train)
    mlflow.log_metric("test_r2", r2_test)
    mae_train = mean_absolute_error(Y_train, Y_train_pred)
    mae_test = mean_absolute_error(Y_test, Y_test_pred)
    mlflow.log_metric("train_mae", mae_train)
    mlflow.log_metric("test_mae", mae_test)
    print(f"R² score on training set: {r2_train:.4f}")
    print(f"R² score on test set: {r2_test:.4f}")
    print(f"MAE on training set: {mae_train:.4f}")
    print(f"MAE on test set: {mae_test:.4f}")
    # Various attributes can be passed to the decorator
    # to modify the information contained in the span
    @mlflow.trace(name = "comparaison", attributes = { "model": "LinearRegression" })
    def trace(r2_test,r2_train):
        str= f"Model: LinearRegression, Test R²: {r2_test}, Train R²: {r2_train}"
        return str
    trace(r2_test,r2_train)
    #signature = infer_signature(X_train,regressor0.predict(X_train_preprocessed))
    input_example = X_train_preprocessed[0:1]
    mlflow.sklearn.log_model(
        sk_model=regressor0,
        name="model0",
        input_example=input_example,
        registered_model_name="getaround-price-prediction-model-linear-regression",
    )
# Sauvegarde locale du modèle avec joblib
joblib.dump(regressor0, "../models/getaround_regressor0_model0.pkl")
# Out:
# 2026/03/10 00:44:58 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/10 00:45:02 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/mlflow/models/model.py:1209: FutureWarning: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is the 'skops' format."
# Registered model 'MODEL0' already exists. Creating a new version of this model...
# 2026/03/10 00:45:13 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: MODEL0, version 3
# Created version '3' of model 'MODEL0'.
# ...

# %% [markdown]
# ## Modèle linéaire Régularisé sur norme L2 (Lasso)

# %% [markdown]
# J'essaie maintenant un modèle régularisé de type Lasso sur un ensemble de meta paramètre pour une optimisation du modèle.

# %%
model1 = Lasso()

# %% [markdown]
# Préparation du modèle Lasso pour un lancement en mode batch _GridSearch_ en _Cross Validation_ pour l'optimisation des meta paramètres.

# %%
params_list = [i/2000 for i in range(0, 100)]
params_list[:10]

param_grid = {
    "alpha": params_list
}
scorer = make_scorer(r2_score)

grid_search = GridSearchCV(
    estimator=model1,
    param_grid=param_grid,
    cv=5,
    scoring=scorer,
    n_jobs=-1
)

# %%
EXPERIMENT_NAME="getaround-price-prediction"
mlflow.set_tracking_uri(os.environ["TRACKING_SERVER_URL"])
mlflow.set_experiment(EXPERIMENT_NAME)
experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)

# Call mlflow autolog
mlflow.sklearn.autolog()
run_description = """
### Modèle amélioré de régression linéaire régularisée pour la prédiction du prix de location de voitures Getaround
Il s'agit d'un modèle plus complexe que le modèel de Base de régression linéaire régularisée (Lasso) avec recherche de grille pour optimiser les hyperparamètres.
    """
with mlflow.start_run(experiment_id = experiment.experiment_id, run_name="Lasso_GridSearchCV_0", description=run_description):
    grid_search.fit(X_train_preprocessed, Y_train)
    
    mlflow.log_params(grid_search.best_params_)

    Y_test_pred = grid_search.predict(X_test_preprocessed)
    r2_test = r2_score(Y_test, Y_test_pred)
    mlflow.log_metric("test_r2", r2_test)

    Y_train_pred = grid_search.predict(X_train_preprocessed)
    r2_train = r2_score(Y_train, Y_train_pred)
    mlflow.log_metric("train_r2", r2_train)


    print("Best parameters:", grid_search.best_params_)
    print("Best cross-validation R²:", grid_search.best_score_)
    print("Test R²:", r2_test)
    print("Train R²:", r2_train)

    # Various attributes can be passed to the decorator
    # to modify the information contained in the span
    @mlflow.trace(name = "comparaison", attributes = { "model": "best_lasso" })
    def trace(grid_search,r2_test,r2_train):
        str= f"Model: best_lasso,Best parameters: {grid_search.best_params_}, Best cross-validation R²: {grid_search.best_score_}, Test R²: {r2_test}, Train R²: {r2_train}"
        return str
    trace(grid_search,r2_test,r2_train)
    #signature = infer_signature(X_train,grid_search.best_estimator_.predict(X_train_preprocessed),grid_search.best_params_)
    input_example = X_train.iloc[0:1].values
    mlflow.sklearn.log_model(
        sk_model=grid_search.best_estimator_,
        name="model1",
        input_example=input_example,
        registered_model_name="getaround-price-prediction-model-lasso-gridsearchcv-0",
    )
# Out:
# 2026/03/10 00:46:13 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/sklearn/base.py:1336: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/sklearn/base.py:1336: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
# Sauvegarde locale du meilleure modèle laso régularisé avec joblib
joblib.dump(grid_search.best_estimator_, "../models/grid_search_lasso_regression_model1.pkl")
# Out:
# ['../models/grid_search_lasso_regression_model1.pkl']

# %% [markdown]
# On reprend le meilleur modèle entre la base _model0_ et le modèle à régularisation optimisée _model1_.
# Pour cela, on examine les performances dans [MLFlow](https://pradelf-getaround-mlflow.hf.space/#/experiments/1) sur Hugging Face où nous avons stockés les modèles et leur entrainement.
#
# ![modèles](./media/mlflow_comparaison_experiment.png)

# %%
# This cell tests the model, with an input example that was part of the logs sent to the tracking server

# model_uri = 's3://dsfsft35-getaround-mlflow-pradelf/Deployment/1/models/m-4c3fa831797840be9a7a902596f83e89/artifacts'

# pyfunc_model = mlflow.pyfunc.load_model(model_uri)
# input_data = pyfunc_model.input_example

# mlflow.models.predict(
#     model_uri=model_uri,
#     input_data=input_data,
#     env_manager="conda",
# )

# %% [markdown]
# ## Modèle de Base ensembliste Random Forest

# %%
# sklearn.ensemble.HistGradientBoostingRegressor

# Automatically detect names of numeric/categorical columns
numeric_features = []
categorical_features = []
for i, t in X.dtypes.items():
    if ("float" in str(t)) or ("int" in str(t)):
        numeric_features.append(i)
    else:
        categorical_features.append(i)

print("Found numeric features ", numeric_features)
print("Found categorical features ", categorical_features)
# Out:
# Found numeric features  ['mileage', 'engine_power']
# Found categorical features  ['model_key', 'fuel', 'paint_color', 'car_type', 'private_parking_available', 'has_gps', 'has_air_conditioning', 'automatic_car', 'has_getaround_connect', 'has_speed_regulator', 'winter_tires']

# %%
## Create pipeline for categorical features
categorical_transformer = OneHotEncoder(
    drop="first"
)  # no missing values in categorical data, so we only need the OHE
#  Use ColumnTransformer to make a preprocessor object that describes all the treatments to be done
preprocessor = ColumnTransformer(
    transformers=[
        ("cat", categorical_transformer, categorical_features),
    ]
)

# %%
# Preprocessings on train set

print("Execution du preprocessing sur le jeu d'entraînement...")
print(X_train.head())
X_train_preprocessed = preprocessor.fit_transform(X_train)
print("...Fait.")
print(
    X_train_preprocessed[0:5]
)  # MUST use this syntax because X_train_preprocessed is a numpy array and not a pandas DataFrame anymore
print()
# Preprocessings on test set
print("Execution du preprocessing sur le jeu de test...")
print(X_test.head())
X_test_preprocessed = preprocessor.transform(
    X_test
)  # Don't fit again !! The test set is used for validating decisions
# we made based on the training set, therefore we can only apply transformations that were parametered using the training set.
# Otherwise this creates what is called a leak from the test set which will introduce a bias in all your results.
print("...Fait.")
print(
    X_test_preprocessed[0:5, :]
)  # MUST use this syntax because X_test is a numpy array and not a pandas DataFrame anymore
print()
# Out:
# Execution du preprocessing sur le jeu d'entraînement...
#      model_key    fuel paint_color   car_type  private_parking_available  \
# id
# 2773   Citroën  diesel       black      sedan                       True
# 3096      Audi  diesel        grey      sedan                       True
# 2936   Renault  diesel        grey      sedan                       True
# 2320   Citroën  diesel       black  hatchback                      False
# 1196   Citroën  diesel       white     estate                      False
#
#       has_gps  has_air_conditioning  automatic_car  has_getaround_connect  \
# id
# 2773     True                 False          False                  False
# 3096     True                 False          False                   True
# 2936     True                 False          False                   True
# 2320    False                 False          False                  False
# 1196     True                 False          False                  False
#
# ...

# %%
# Perform grid search
print("Grid search...")
regressor3 = RandomForestRegressor()

# Grid of values to be tested
params = {
    "max_depth": [2, 4, 6, 8, 10],
    "min_samples_leaf": [1, 2, 5],
    "min_samples_split": [2, 4, 8],
    "n_estimators": [10, 20, 40, 60, 80, 100],
}
EXPERIMENT_NAME="getaround-price-prediction"
mlflow.set_tracking_uri(os.environ["TRACKING_SERVER_URL"])
mlflow.set_experiment(EXPERIMENT_NAME)
experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)

# Call mlflow autolog
mlflow.sklearn.autolog(registered_model_name="getaround-price-prediction-model-randomforest-gridsearchcv-0")
run_description = """
### Modèle de type Random Forest avec recherche sur grille pour la prédiction du prix de location de voitures Getaround
Il s'agit d'un modèle plus complexe que les modèles de régression linéaire, avec recherche sur grille pour optimiser les hyperparamètres. 
Ce modèle est plus puissant que les modèles linéaires, mais aussi plus coûteux en termes de temps d'entraînement et de ressources. Il est important de comparer les performances de ce modèle avec les modèles linéaires pour évaluer si l'augmentation de la complexité du modèle se traduit par une amélioration significative des performances.
    """
with mlflow.start_run(experiment_id = experiment.experiment_id, run_name="RandomForest_GridSearchCV_0", description=run_description):
    gridsearch2 = GridSearchCV(
        regressor3, param_grid=params, cv=3
    )  # cv : the number of folds to be used for CV
    gridsearch2.fit(X_train_preprocessed, Y_train)
    print("...Fait.")
    print("Best hyperparameters : ", gridsearch2.best_params_)
    print("Best cross-validation R²:", gridsearch2.best_score_)

    mlflow.log_params(gridsearch2.best_params_)
    print("Best parameters:", gridsearch2.best_params_)

    # Predictions on test set
    Y_test_pred = gridsearch2.predict(X_test_preprocessed)
    r2_test = r2_score(Y_test, Y_test_pred)
    mlflow.log_metric("test_r2", r2_test)
    print("Test R²:", r2_test)

    # Predictions on training set
    print("Predictions sur le jeu d'entrainement...")
    Y_train_pred = gridsearch2.predict(X_train_preprocessed)
    r2_train = r2_score(Y_train, Y_train_pred)
    mlflow.log_metric("train_r2", r2_train)
    print("Train R²:", r2_train)
    print("...Fait.")
    print()
    # Various attributes can be passed to the decorator
    # to modify the information contained in the span
    @mlflow.trace(name = "comparaison", attributes = { "model": "RandomForestRegressor" })
    def trace(grid_search,r2_test,r2_train):
        str= f"Model: RandomForestRegressor, Best parameters: {grid_search.best_params_}, Best cross-validation R²: {grid_search.best_score_}, Test R²: {r2_test}, Train R²: {r2_train}"
        return str
    trace(gridsearch2,r2_test,r2_train)
    #signature = infer_signature(X_train,gridsearch2.best_estimator_.predict(X_train_preprocessed))
    input_example = X_train.iloc[:1]
    mlflow.sklearn.log_model(
        sk_model=gridsearch2.best_estimator_,
        name="model3",
        input_example=input_example,
        registered_model_name="getaround-price-prediction-model-randomforest-gridsearchcv-0",
    )
# Out:
# Grid search...
# 2026/03/10 00:55:18 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'

# %%
# Sauvegarde locale du meilleure modèle RandomForest régularisé avec joblib
joblib.dump(gridsearch2.best_estimator_, "../models/grid_search_cv_randomforest_regression_model3.pkl")
# Out:
# ['../models/grid_search_cv_randomforest_regression_model3.pkl']

# %% [markdown]
# ## Modèle de Forêt Histogram-Based Gradient Boosting Speed

# %%
categorical_cols = ["model_key", "fuel", "paint_color", "car_type", "private_parking_available", "has_gps", "has_air_conditioning",
                    "automatic_car", "has_getaround_connect", "has_speed_regulator", "winter_tires"]
numerical_cols = ["mileage", "engine_power"]

X = pricing_df[categorical_cols + numerical_cols]
Y = pricing_df["rental_price_per_day"]

bins = pd.qcut(Y, q=4, duplicates="drop")
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y,
    train_size=0.75,
    random_state=42,
    stratify=bins
)

onehot_encoder = OneHotEncoder(drop="first", handle_unknown="ignore")


# Preprocessing des données avec ColumnTransformer pour appliquer les transformations appropriées aux colonnes catégorielles et numériques
preprocessor = ColumnTransformer(
    transformers=[
        ("categorical", onehot_encoder, categorical_cols)
    ]
)
# Application du préprocesseur aux données d'entraînement et de test
X_train_preprocessed = preprocessor.fit_transform(X_train)
X_test_preprocessed = preprocessor.transform(X_test)

# %%
mlflow.sklearn.autolog(registered_model_name="getaround-price-prediction-model-histgradientboosting-0")
run_description = """
### Modèle de type Boost HistGradientBoostingRegressor

    """
with mlflow.start_run(experiment_id = experiment.experiment_id, run_name="RandomForHistGradientBoostingRegressor_0", description=run_description):
    # Create and train the HistGradientBoostingRegressor model
    model4 = HistGradientBoostingRegressor() #max_iter=100, max_bins=50, max_depth=10, min_samples_leaf=20
    model4.fit(X_train_preprocessed.toarray(), Y_train)
    # Predictions on test set
    Y_test_pred = model4.predict(X_test_preprocessed.toarray())
    r2_test = r2_score(Y_test, Y_test_pred)
    mlflow.log_metric("test_r2", r2_test)
    print("Test R²:", r2_test)

    # Predictions on training set
    print("Predictions sur le jeu d'entrainement...")
    Y_train_pred = model4.predict(X_train_preprocessed.toarray())
    r2_train = r2_score(Y_train, Y_train_pred)
    mlflow.log_metric("train_r2", r2_train)
    print("Train R²:", r2_train)
    print("...Fait.")
    print()
    # Various attributes can be passed to the decorator
    # to modify the information contained in the span
    @mlflow.trace(name = "comparaison", attributes = { "model": "HistGradientBoostingRegressor" })
    def trace(r2_test,r2_train):
        str= f"Model: HistGradientBoostingRegressor, Test R²: {r2_test}, Train R²: {r2_train}"
        return str
    trace(r2_test,r2_train)     
    #signature = infer_signature(X_train,gridsearch2.best_estimator_.predict(X_train_preprocessed))
    #input_example = X_train.iloc[:1]
    # mlflow.sklearn.log_model(
    #     sk_model=model4,
    #     name="model4",
    #     #input_example=input_example,
    #     registered_model_name="getaround-price-prediction-model-histgradientboosting-0",
    # )
# Out:
# 2026/03/10 00:51:05 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# 2026/03/10 00:51:11 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/mlflow/models/model.py:1209: FutureWarning: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is the 'skops' format."
# Registered model 'getaround-price-prediction-model-histgradientboosting-0' already exists. Creating a new version of this model...
# ...

# %%
# Sauvegarde locale du modèle HistGradientBoostingRegressor régularisé avec joblib
joblib.dump(gridsearch2.best_estimator_, "../models/HistGradientBoostingRegressor_regression_model4.pkl")
# Out:
# ['../models/HistGradientBoostingRegressor_regression_model4.pkl']

# %% [markdown]
# Le modèle sélectionné, ici la regvression linéaire simple (__model0__) est déployé en web service sur l'URL du space hugging face. On trouve la documentation de l'API à l'adresse : [https://pradelf-getaround-api.hf.space/docs](https://pradelf-getaround-api.hf.space/docs)
