# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error


from scipy.stats import randint, uniform, loguniform
from sklearn.model_selection import RandomizedSearchCV, KFold, train_test_split

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression

import os
from dotenv import load_dotenv

import warnings
warnings.filterwarnings("ignore", message="Found unknown categories")




from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import r2_score, make_scorer
from dotenv import load_dotenv
import pandas as pd

import joblib
import os

# %%
import mlflow
from mlflow.models import infer_signature
from mlflow.tracking import MlflowClient

# %%
pricing_df = pd.read_csv("https://huggingface.co/datasets/pradelf/getaround-dataset/resolve/main/get_around_pricing_project.csv", index_col=0)
pricing_df.head()
# Out:
#    model_key  mileage  engine_power    fuel paint_color     car_type  \
# id
# 0    Citroën   140411           100  diesel       black  convertible
# 1    Citroën    13929           317  petrol        grey  convertible
# 2    Citroën   183297           120  diesel       white  convertible
# 3    Citroën   128035           135  diesel         red  convertible
# 4    Citroën    97097           160  diesel      silver  convertible
#
#     private_parking_available  has_gps  has_air_conditioning  automatic_car  \
# id
# 0                        True     True                 False          False
# 1                        True     True                 False          False
# 2                       False    False                 False          False
# 3                        True     True                 False          False
# 4                        True     True                 False          False
#
#     has_getaround_connect  has_speed_regulator  winter_tires  \
# id
# 0                    True                 True          True
# 1                   False                 True          True
# 2                    True                False          True
# 3                    True                 True          True
# 4                   False                 True          True
#
#     rental_price_per_day
# id
# 0                    106
# 1                    264
# 2                    101
# 3                    158
# 4                    183

# %%
params_list = [i/2000 for i in range(1, 100)]
params_list[:10]
# Out:
# [0.0005, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045, 0.005]

# %%
import mlflow
from mlflow.models import infer_signature
from mlflow.tracking import MlflowClient

load_dotenv()

categorical_cols = ["model_key", "fuel", "paint_color", "car_type", "private_parking_available", "has_gps", "has_air_conditioning",
                    "automatic_car", "has_getaround_connect", "has_speed_regulator", "winter_tires"]
numerical_cols = ["mileage", "engine_power"]

X = pricing_df[categorical_cols + numerical_cols]
y = pricing_df["rental_price_per_day"]

bins = pd.qcut(y, q=4, duplicates="drop")
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    train_size=0.75,
    random_state=444719,
    stratify=bins
)

onehot_encoder = OneHotEncoder(drop="first", handle_unknown="ignore")
standard_scaler = StandardScaler()

preprocessor = ColumnTransformer(
    transformers=[
        ("categorical", onehot_encoder, categorical_cols),
        ("numerical", standard_scaler, numerical_cols)
    ]
)

model = Lasso()  # or Ridge()

pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("regressor", model)
])

param_grid = {
    "regressor__alpha": params_list
}

scorer = make_scorer(r2_score)

grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=5,
    scoring=scorer,
    n_jobs=-1
)

EXPERIMENT_NAME="getaround-price-prediction"
mlflow.set_tracking_uri(os.environ["TRACKING_SERVER_URL"])
mlflow.set_experiment(EXPERIMENT_NAME)
experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)

with mlflow.start_run(experiment_id = experiment.experiment_id, run_name="Lasso_GridSearchCV_1"):
    grid_search.fit(X_train, y_train)

    mlflow.log_params(grid_search.best_params_)

    y_pred = grid_search.predict(X_test)
    r2 = r2_score(y_test, y_pred)

    mlflow.log_metric("test_r2", r2)

    print("Best parameters:", grid_search.best_params_)
    print("Best cross-validation R²:", grid_search.best_score_)
    print("Test R²:", r2)

    input_example = X_train.iloc[:1]
    mlflow.sklearn.log_model(
        grid_search.best_estimator_,
        "model",
        input_example=input_example,
        registered_model_name="getaround-price-prediction-model"
    )

    # joblib.dump(grid_search.best_estimator_, "linear_regression_model.pkl")
# Out:
# /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:675: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.532e+03, tolerance: 3.194e+02
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:675: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.645e+04, tolerance: 3.311e+02
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:675: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.446e+04, tolerance: 3.171e+02
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:675: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.674e+04, tolerance: 3.244e+02
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:675: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.907e+03, tolerance: 3.194e+02
#   model = cd_fast.sparse_enet_coordinate_descent(
# /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:675: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.840e+02, tolerance: 3.194e+02
#   model = cd_fast.sparse_enet_coordinate_descent(
# 2026/02/09 10:31:35 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Best parameters: {'regressor__alpha': 0.0085}
# Best cross-validation R²: 0.6961471561171931
# Test R²: 0.7020558138674311
# /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/mlflow/models/model.py:1209: FutureWarning: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is the 'skops' format.
#   flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 🏃 View run Lasso_GridSearchCV_1 at: https://pradelf-getaround-mlflow.hf.space/#/experiments/1/runs/f617d19e3668485ebef600832f4de386
# 🧪 View experiment at: https://pradelf-getaround-mlflow.hf.space/#/experiments/1
# ---------------------------------------------------------------------------
# AccessDenied                              Traceback (most recent call last)
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/boto3/s3/transfer.py:452, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     451 try:
# --> 452     future.result()
#     453 # If a client error was raised, add the backwards compatibility layer
#     454 # that raises a S3UploadFailedError. These specific errors were only
#     455 # ever thrown for upload_parts but now can be thrown for any related
#     456 # client error.
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/s3transfer/futures.py:111, in TransferFuture.result(self)
#     107 try:
#     108     # Usually the result() method blocks until the transfer is done,
#     109     # however if a KeyboardInterrupt is raised we want want to exit
#     110     # out of this and propagate the exception.
# --> 111     return self._coordinator.result()
#     112 except KeyboardInterrupt as e:
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/s3transfer/futures.py:287, in TransferCoordinator.result(self)
#     286 if self._exception:
# --> 287     raise self._exception
#     288 return self._result
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/s3transfer/tasks.py:142, in Task.__call__(self, ctx)
#     141     if not self._transfer_coordinator.done():
# --> 142         return self._execute_main(kwargs)
#     143 except Exception as e:
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/s3transfer/tasks.py:165, in Task._execute_main(self, kwargs)
#     163 logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> 165 return_value = self._main(**kwargs)
#     166 # If the task is the final task, then set the TransferFuture's
#     167 # value to the return value from main().
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/s3transfer/upload.py:796, in PutObjectTask._main(self, client, fileobj, bucket, key, extra_args)
#     795 with fileobj as body:
# --> 796     client.put_object(Bucket=bucket, Key=key, Body=body, **extra_args)
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/botocore/client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#
# AccessDenied: An error occurred (AccessDenied) when calling the PutObject operation: User: arn:aws:iam::571127933775:user/dsfsft35-mlflow is not authorized to perform: s3:PutObject on resource: "arn:aws:s3:::dsfsft35-getaround-mlflow-pradelf/Deployment/1/models/m-fc6eac3fc6784059ad4ac410b98dc2bf/artifacts/python_env.yaml" because no identity-based policy allows the s3:PutObject action
#
# During handling of the above exception, another exception occurred:
#
# S3UploadFailedError                       Traceback (most recent call last)
# Cell In[10], line 73
#      70 print("Test R²:", r2)
#      72 input_example = X_train.iloc[:1]
# ---> 73 mlflow.sklearn.log_model(
#      74     grid_search.best_estimator_,
#      75     "model",
#      76     input_example=input_example,
#      77     registered_model_name="getaround-price-prediction-model"
#      78 )
#      80 # joblib.dump(grid_search.best_estimator_, "linear_regression_model.pkl")
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/mlflow/sklearn/__init__.py:466, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata, params, tags, model_type, step, model_id, name, skops_trusted_types)
#     370 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     371 def log_model(
#     372     sk_model,
#    (...)    392     skops_trusted_types: list[str] | None = None,
#     393 ):
#     394     """
#     395     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     396     containing the following flavors:
#    (...)    464
#     465     """
# --> 466     return Model.log(
#     467         artifact_path=artifact_path,
#     468         name=name,
#     469         flavor=mlflow.sklearn,
#     470         sk_model=sk_model,
#     471         conda_env=conda_env,
#     472         code_paths=code_paths,
#     473         serialization_format=serialization_format,
#     474         registered_model_name=registered_model_name,
#     475         signature=signature,
#     476         input_example=input_example,
#     477         await_registration_for=await_registration_for,
#     478         pip_requirements=pip_requirements,
#     479         extra_pip_requirements=extra_pip_requirements,
#     480         pyfunc_predict_fn=pyfunc_predict_fn,
#     481         metadata=metadata,
#     482         params=params,
#     483         tags=tags,
#     484         model_type=model_type,
#     485         step=step,
#     486         model_id=model_id,
#     487         skops_trusted_types=skops_trusted_types,
#     488     )
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/mlflow/models/model.py:1288, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, auth_policy, prompts, name, model_type, params, tags, step, model_id, **kwargs)
#    1285     # mlflow_model is updated, rewrite the MLmodel file
#    1286     mlflow_model.save(os.path.join(local_path, MLMODEL_FILE_NAME))
# -> 1288 client.log_model_artifacts(model.model_id, local_path)
#    1289 # If the model was previously identified as external, delete the tag because
#    1290 # the model now has artifacts in MLflow Model format
#    1291 if model.tags.get(MLFLOW_MODEL_IS_EXTERNAL, "false").lower() == "true":
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/mlflow/tracking/client.py:5800, in MlflowClient.log_model_artifacts(self, model_id, local_dir)
#    5789 def log_model_artifacts(self, model_id: str, local_dir: str) -> None:
#    5790     """
#    5791     Upload a set of artifacts to the specified logged model.
#    5792
#    (...)   5798         None
#    5799     """
# -> 5800     return self._tracking_client.log_model_artifacts(model_id, local_dir)
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/client.py:911, in TrackingServiceClient.log_model_artifacts(self, model_id, local_dir)
#     910 def log_model_artifacts(self, model_id: str, local_dir: str) -> None:
# --> 911     self._get_artifact_repo(model_id, resource="logged_model").log_artifacts(local_dir)
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/mlflow/store/artifact/s3_artifact_repo.py:305, in S3ArtifactRepository.log_artifacts(self, local_dir, artifact_path)
#     302     upload_path = posixpath.join(dest_path, rel_path)
#     304 for f in filenames:
# --> 305     self._upload_file(
#     306         s3_client=s3_client,
#     307         local_file=os.path.join(root, f),
#     308         bucket=bucket,
#     309         key=posixpath.join(upload_path, f),
#     310     )
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/mlflow/store/artifact/s3_artifact_repo.py:253, in S3ArtifactRepository._upload_file(self, s3_client, local_file, bucket, key)
#     251 if environ_extra_args is not None:
#     252     extra_args.update(environ_extra_args)
# --> 253 s3_client.upload_file(Filename=local_file, Bucket=bucket, Key=key, ExtraArgs=extra_args)
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/boto3/s3/inject.py:175, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     140 """Upload a file to an S3 object.
#     141
#     142 Usage::
#    (...)    172     transfer.
#     173 """
#     174 with S3Transfer(self, Config) as transfer:
# --> 175     return transfer.upload_file(
#     176         filename=Filename,
#     177         bucket=Bucket,
#     178         key=Key,
#     179         extra_args=ExtraArgs,
#     180         callback=Callback,
#     181     )
#
# File /Volumes/MyTravel/Formation/Jedha/Jedha-dsfs-ft-35/Projets/getaround/Projet/getaround/venv/lib/python3.12/site-packages/boto3/s3/transfer.py:458, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     453 # If a client error was raised, add the backwards compatibility layer
#     454 # that raises a S3UploadFailedError. These specific errors were only
#     455 # ever thrown for upload_parts but now can be thrown for any related
#     456 # client error.
#     457 except ClientError as e:
# --> 458     raise S3UploadFailedError(
#     459         f"Failed to upload {filename} to {bucket}/{key}: {e}"
#     460     )
#
# S3UploadFailedError: Failed to upload /var/folders/6m/4bfx39_j0519_3g3r0sp6fbw0000gn/T/tmpnox4aibw/model/python_env.yaml to dsfsft35-getaround-mlflow-pradelf/Deployment/1/models/m-fc6eac3fc6784059ad4ac410b98dc2bf/artifacts/python_env.yaml: An error occurred (AccessDenied) when calling the PutObject operation: User: arn:aws:iam::571127933775:user/dsfsft35-mlflow is not authorized to perform: s3:PutObject on resource: "arn:aws:s3:::dsfsft35-getaround-mlflow-pradelf/Deployment/1/models/m-fc6eac3fc6784059ad4ac410b98dc2bf/artifacts/python_env.yaml" because no identity-based policy allows the s3:PutObject action

# %%
# This cell tests the model, with an input example that was part of the logs sent to the tracking server
import mlflow
from mlflow.models import Model
from dotenv import load_dotenv

load_dotenv()

model_uri = 's3://getaround-mlflow-artifactstore/2/b21d60925615456587e03b92d95843c4/artifacts/model'

pyfunc_model = mlflow.pyfunc.load_model(model_uri)
input_data = pyfunc_model.input_example

mlflow.models.predict(
    model_uri=model_uri,
    input_data=input_data,
    env_manager="virtualenv",
)

# %%
import sklearn
print(sklearn.__version__)
